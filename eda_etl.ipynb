# %%
import pandas as pd

# %%
#Ingestamos los datos
amazon = pd.read_csv("amazon_prime_titles.csv")
netflix = pd.read_csv("netflix_titles.csv")
hulu = pd.read_csv("hulu_titles.csv")
disney = pd.read_csv("disney_plus_titles.csv")

# %% [markdown]
# # Visualizamos los datos

# %%
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# ...

# %%
disney.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %% [markdown]
# #Generamos el campo "id"

# %%
amazon.insert(loc=0, column="id", value="a" + amazon["show_id"])
netflix.insert(loc=0, column="id", value="n" + netflix["show_id"])
hulu.insert(loc=0, column="id", value="h" + hulu["show_id"])
disney.insert(loc=0, column="id", value="d" + disney["show_id"])

# %%
#Verificamos
amazon.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  Movie   The Grand Seduction    Don McKellar
# 1  as2      s2  Movie  Take Care Good Night    Girish Joshi
# 2  as3      s3  Movie  Secrets of Deception     Josh Webber
# 3  as4      s4  Movie    Pink: Staying True  Sonia Anderson
# 4  as5      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# # Concatenamos los 4 datasets

# %%
df = amazon.append(netflix).append(hulu).append(disney)

# %%
df.isna().sum()
# Out:
# id                  0
# show_id             0
# type                0
# title               0
# director         8259
# cast             5321
# country         11499
# date_added       9554
# release_year        0
# rating            864
# duration          482
# listed_in           0
# description         4
# dtype: int64

# %%
df.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  Movie   The Grand Seduction    Don McKellar
# 1  as2      s2  Movie  Take Care Good Night    Girish Joshi
# 2  as3      s3  Movie  Secrets of Deception     Josh Webber
# 3  as4      s4  Movie    Pink: Staying True  Sonia Anderson
# 4  as5      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# # Reemplazamos los valores nulos del campo rating por “G”

# %%
df["rating"].fillna("G", inplace=True)

# %%
df.isna().sum()
# Out:
# id                  0
# show_id             0
# type                0
# title               0
# director         8259
# cast             5321
# country         11499
# date_added       9554
# release_year        0
# rating              0
# duration          482
# listed_in           0
# description         4
# dtype: int64

# %% [markdown]
# # Se cambia el formato de fecha a "AAAA-mm-dd"

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  Movie   The Grand Seduction    Don McKellar
# 1  as2      s2  Movie  Take Care Good Night    Girish Joshi
# 2  as3      s3  Movie  Secrets of Deception     Josh Webber
# 3  as4      s4  Movie    Pink: Staying True  Sonia Anderson
# 4  as5      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      G  113 min            Comedy, Drama
# ...

# %% [markdown]
# # Cambiamos todos los campos que sean texto a minúsculas

# %%
df["type"] = df["type"].str.lower()
df["title"] = df["title"].str.lower()
df["director"] = df["director"].str.lower()
df["cast"] = df["cast"].str.lower()
df["country"] = df["country"].str.lower()
df["rating"] = df["rating"].str.lower()
df["duration"] = df["duration"].str.lower()
df["listed_in"] = df["listed_in"].str.lower()
df["description"] = df["description"].str.lower()

# %%
df.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  movie   the grand seduction    don mckellar
# 1  as2      s2  movie  take care good night    girish joshi
# 2  as3      s3  movie  secrets of deception     josh webber
# 3  as4      s4  movie    pink: staying true  sonia anderson
# 4  as5      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      g  113 min            comedy, drama
# ...

# %% [markdown]
# # Separamos el campo "duration" en dos

# %%
#Separamos la columna
df[["duration_int", "duration_type"]] = df["duration"].str.split(" ", n=1, expand=True)

# %%
df.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  movie   the grand seduction    don mckellar
# 1  as2      s2  movie  take care good night    girish joshi
# 2  as3      s3  movie  secrets of deception     josh webber
# 3  as4      s4  movie    pink: staying true  sonia anderson
# 4  as5      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      g  113 min            comedy, drama
# ...

# %%
#Eliminamos la columna "duration"
df = df.drop("duration", axis=1)

# %%
df.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  movie   the grand seduction    don mckellar
# 1  as2      s2  movie  take care good night    girish joshi
# 2  as3      s3  movie  secrets of deception     josh webber
# 3  as4      s4  movie    pink: staying true  sonia anderson
# 4  as5      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating                listed_in  \
# 0 2021-03-30          2014      g            comedy, drama
# 1 2021-03-30          2018    13+     drama, international
# ...

# %% [markdown]
# # **Ahora trabajamos con los 8 csv**

# %%
#Ingestamos todos los csv mediante un bucle
ratings = ["1.csv", "2.csv", "3.csv", "4.csv", "5.csv", "6.csv", "7.csv", "8.csv"]
new_df = []
for rating in ratings:
    df1 = pd.read_csv(rating)
    new_df.append(df1)

# %%
#Unimos los 8 csv en uno solo
r = pd.concat(new_df, axis=0, ignore_index=True)

# %%
r.head()
# Out:
#    userId  rating   timestamp movieId
# 0       1     1.0  1425941529   as680
# 1       1     4.5  1425942435  ns2186
# 2       1     5.0  1425941523  hs2381
# 3       1     5.0  1425941546  ns3663
# 4       1     5.0  1425941556  as9500

# %%
#Cambiamos la columna "timestamp" con formato "Año-Mes-Día"
r['timestamp'] = pd.to_datetime(r['timestamp'], unit='s')
r['timestamp'] = r['timestamp'].dt.strftime('%Y-%m-%d')

# %% [markdown]
# # Calculamos el "score"

# %%
#Usamos "moviesId" y calculamos el promedio
r_score = r.groupby("movieId")["rating"].mean()

#Creamos la columna "score" e inputamos los valores promediados a la columna "score" mediante "movieId"
r["score"] = r["movieId"].map(r_score)

# %%
r.head()
# Out:
#    userId  rating   timestamp movieId     score
# 0       1     1.0  2015-03-09   as680  3.549127
# 1       1     4.5  2015-03-09  ns2186  3.556886
# 2       1     5.0  2015-03-09  hs2381  3.604124
# 3       1     5.0  2015-03-09  ns3663  3.547085
# 4       1     5.0  2015-03-09  as9500  3.532158

# %%
#Unimos los DataFrame de plataformas con los 8 csv
movies_df = pd.merge(df, r, left_on='id', right_on="movieId")

# %%
movies_df.shape
movies_df.head()
# Out:
#     id show_id   type                title      director  \
# 0  as1      s1  movie  the grand seduction  don mckellar
# 1  as1      s1  movie  the grand seduction  don mckellar
# 2  as1      s1  movie  the grand seduction  don mckellar
# 3  as1      s1  movie  the grand seduction  don mckellar
# 4  as1      s1  movie  the grand seduction  don mckellar
#
#                                              cast country date_added  \
# 0  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 1  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 2  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 3  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 4  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
#
#    release_year rating_x      listed_in  \
# 0          2014        g  comedy, drama
# 1          2014        g  comedy, drama
# 2          2014        g  comedy, drama
# ...

# %% [markdown]
# # Eliminamos columnas que no sirvan o se repitan

# %%
movies_df = movies_df.drop("movieId", axis=1)

# %%
movies_df.head()
# Out:
#     id show_id   type                title      director  \
# 0  as1      s1  movie  the grand seduction  don mckellar
# 1  as1      s1  movie  the grand seduction  don mckellar
# 2  as1      s1  movie  the grand seduction  don mckellar
# 3  as1      s1  movie  the grand seduction  don mckellar
# 4  as1      s1  movie  the grand seduction  don mckellar
#
#                                              cast country date_added  \
# 0  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 1  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 2  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 3  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
# 4  brendan gleeson, taylor kitsch, gordon pinsent  canada 2021-03-30
#
#    release_year rating_x      listed_in  \
# 0          2014        g  comedy, drama
# 1          2014        g  comedy, drama
# 2          2014        g  comedy, drama
# ...

# %% [markdown]
# # Exportamos todo en un archivo csv

# %%
movies_df.to_csv("titles_mvs.csv", index=False)
